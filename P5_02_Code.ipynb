# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_popul_2018=pd.read_csv('C:\\Users\\nassc\Desktop\\popul2018.csv')
data_popul_2015=pd.read_csv('C:\\Users\\nassc\Desktop\\popul2015.csv')

# %%
data_popul_2018
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 232           OA  Séries temporelles annuelles              236
# 233           OA  Séries temporelles annuelles              237
# 234           OA  Séries temporelles annuelles              249
# 235           OA  Séries temporelles annuelles              251
# 236           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_popul_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            237 non-null    object
#  1   Domaine                 237 non-null    object
#  2   Code zone (FAO)         237 non-null    int64
#  3   Zone                    237 non-null    object
#  4   Code Élément            237 non-null    int64
#  5   Élément                 237 non-null    object
#  6   Code Produit            237 non-null    int64
#  7   Produit                 237 non-null    object
#  8   Code année              237 non-null    int64
#  9   Année                   237 non-null    int64
#  10  Unité                   237 non-null    object
#  11  Valeur                  237 non-null    float64
#  12  Symbole                 237 non-null    object
#  13  Description du Symbole  237 non-null    object
# ...

# %%
data_popul_2015
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 232           OA  Séries temporelles annuelles              236
# 233           OA  Séries temporelles annuelles              237
# 234           OA  Séries temporelles annuelles              249
# 235           OA  Séries temporelles annuelles              251
# 236           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_popul_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            237 non-null    object
#  1   Domaine                 237 non-null    object
#  2   Code zone (FAO)         237 non-null    int64
#  3   Zone                    237 non-null    object
#  4   Code Élément            237 non-null    int64
#  5   Élément                 237 non-null    object
#  6   Code Produit            237 non-null    int64
#  7   Produit                 237 non-null    object
#  8   Code année              237 non-null    int64
#  9   Année                   237 non-null    int64
#  10  Unité                   237 non-null    object
#  11  Valeur                  237 non-null    float64
#  12  Symbole                 237 non-null    object
#  13  Description du Symbole  237 non-null    object
# ...

# %%
data_popul_2018=data_popul_2018[-(data_popul_2018['Zone']=='Chine')]

# %%
data_popul_2018
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 232           OA  Séries temporelles annuelles              236
# 233           OA  Séries temporelles annuelles              237
# 234           OA  Séries temporelles annuelles              249
# 235           OA  Séries temporelles annuelles              251
# 236           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_popul_2018=data_popul_2018[-(data_popul_2018['Zone']=='France')]

# %%
data_popul_2018
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 232           OA  Séries temporelles annuelles              236
# 233           OA  Séries temporelles annuelles              237
# 234           OA  Séries temporelles annuelles              249
# 235           OA  Séries temporelles annuelles              251
# 236           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_popul_2015=data_popul_2015[-(data_popul_2015['Zone']=='Chine')]

# %%
data_popul_2015
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 232           OA  Séries temporelles annuelles              236
# 233           OA  Séries temporelles annuelles              237
# 234           OA  Séries temporelles annuelles              249
# 235           OA  Séries temporelles annuelles              251
# 236           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_popul_2015=data_popul_2015[-(data_popul_2015['Zone']=='France')]

# %%
data_popul_2015
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 232           OA  Séries temporelles annuelles              236
# 233           OA  Séries temporelles annuelles              237
# 234           OA  Séries temporelles annuelles              249
# 235           OA  Séries temporelles annuelles              251
# 236           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_popul=data_popul_2018.merge(data_popul_2015[['Zone','Valeur']], how='left',on=['Zone'])

# %%
data_popul
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 230           OA  Séries temporelles annuelles              236
# 231           OA  Séries temporelles annuelles              237
# 232           OA  Séries temporelles annuelles              249
# 233           OA  Séries temporelles annuelles              251
# 234           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %% [markdown]
# # la difference de popul2018-2015 en pourcentage

# %%
data_popul['diff_popu_pourc']= 100*(data_popul['Valeur_x']-data_popul['Valeur_y'])/(data_popul['Valeur_y'])

# %%
data_popul['diff_popu_pourc']
# Out:
# 0      8.015197
# 1      4.344302
# 2     -0.268914
# 3      6.293751
# 4      1.634734
#          ...
# 230   -3.971537
# 231    3.095572
# 232    7.550768
# 233    9.272080
# 234    4.518203
# Name: diff_popu_pourc, Length: 235, dtype: float64

# %%
data_popul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 0 to 234
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            235 non-null    object
#  1   Domaine                 235 non-null    object
#  2   Code zone (FAO)         235 non-null    int64
#  3   Zone                    235 non-null    object
#  4   Code Élément            235 non-null    int64
#  5   Élément                 235 non-null    object
#  6   Code Produit            235 non-null    int64
#  7   Produit                 235 non-null    object
#  8   Code année              235 non-null    int64
#  9   Année                   235 non-null    int64
#  10  Unité                   235 non-null    object
#  11  Valeur_x                235 non-null    float64
#  12  Symbole                 235 non-null    object
#  13  Description du Symbole  235 non-null    object
# ...

# %% [markdown]
# # Proportion de protéines animale par rapport à la quantité totale de protéines dans la disponibilité alimentaire du pays

# %%
data_proteine_anim=pd.read_csv('C:\\Users\\nassc\Desktop\\proteinesproduitsanimaux.csv')
data_dispo_proteines=pd.read_csv('C:\\Users\\nassc\Desktop\\dispoproteines.csv')
data_alim=pd.read_csv('C:\\Users\\nassc\Desktop\\complet.csv')

# %%
data_proteine_anim
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_proteine_anim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            173 non-null    object
#  1   Domaine                 173 non-null    object
#  2   Code zone (FAO)         173 non-null    int64
#  3   Zone                    173 non-null    object
#  4   Code Élément            173 non-null    int64
#  5   Élément                 173 non-null    object
#  6   Code Produit            173 non-null    int64
#  7   Produit                 173 non-null    object
#  8   Code année              173 non-null    int64
#  9   Année                   173 non-null    int64
#  10  Unité                   173 non-null    object
#  11  Valeur                  173 non-null    float64
#  12  Symbole                 173 non-null    object
#  13  Description du Symbole  173 non-null    object
# ...

# %%
data_dispo_proteines
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_dispo_proteines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            173 non-null    object
#  1   Domaine                 173 non-null    object
#  2   Code zone (FAO)         173 non-null    int64
#  3   Zone                    173 non-null    object
#  4   Code Élément            173 non-null    int64
#  5   Élément                 173 non-null    object
#  6   Code Produit            173 non-null    int64
#  7   Produit                 173 non-null    object
#  8   Code année              173 non-null    int64
#  9   Année                   173 non-null    int64
#  10  Unité                   173 non-null    object
#  11  Valeur                  173 non-null    float64
#  12  Symbole                 173 non-null    object
#  13  Description du Symbole  173 non-null    object
# ...

# %%
data_proteine_anim=data_proteine_anim[-(data_proteine_anim['Zone']=='Chine')]

# %%
data_proteine_anim
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_proteine_anim=data_proteine_anim[-(data_proteine_anim['Zone']=='France')]

# %%
data_proteine_anim
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_dispo_proteines=data_dispo_proteines[-(data_dispo_proteines['Zone']=='Chine')]

# %%
data_dispo_proteines
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_dispo_proteines=data_dispo_proteines[-(data_dispo_proteines['Zone']=='France')]

# %%
data_dispo_proteines
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_proteine_anim.rename(columns={'Valeur':'Prot_anim'},inplace=True)
# Out:
# C:\Users\nassc\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data_proteine_anim
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_dispo_proteines.rename(columns={'Valeur':'Dispo_prot'},inplace=True)
# Out:
# C:\Users\nassc\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data_dispo_proteines
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_proteines=data_dispo_proteines.merge(data_proteine_anim[['Zone','Prot_anim']], how='left',on=['Zone'])

# %%
data_proteines
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 166          FBS  Nouveaux Bilans Alimentaire              236
# 167          FBS  Nouveaux Bilans Alimentaire              237
# 168          FBS  Nouveaux Bilans Alimentaire              249
# 169          FBS  Nouveaux Bilans Alimentaire              251
# 170          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           674
# 1                            Afrique du Sud           674
# ...

# %%
data_popul1=data_popul[(data_popul['Zone'].isin(data_proteines['Zone']))]

# %%
data_popul1
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 230           OA  Séries temporelles annuelles              236
# 231           OA  Séries temporelles annuelles              237
# 232           OA  Séries temporelles annuelles              249
# 233           OA  Séries temporelles annuelles              251
# 234           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_proteines_popul=data_popul1.merge(data_proteines[['Zone','Dispo_prot','Prot_anim']], how='left',on=['Zone'])

# %%
data_proteines_popul
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 166           OA  Séries temporelles annuelles              236
# 167           OA  Séries temporelles annuelles              237
# 168           OA  Séries temporelles annuelles              249
# 169           OA  Séries temporelles annuelles              251
# 170           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_proteines_popul['Prop_prot']=data_proteines_popul['Prot_anim']/data_proteines_popul['Dispo_prot']

# %%
data_proteines_popul
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 166           OA  Séries temporelles annuelles              236
# 167           OA  Séries temporelles annuelles              237
# 168           OA  Séries temporelles annuelles              249
# 169           OA  Séries temporelles annuelles              251
# 170           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data_proteines_popul['prot_hab']=data_proteines_popul['Dispo_prot']/1000

# %%
data_calo_hab=pd.read_csv('C:\\Users\\nassc\Desktop\\calohab.csv')

# %%
data_calo_hab
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           664
# 1                            Afrique du Sud           664
# ...

# %%
data_calo_hab.rename(columns={'Valeur':'Calo_hab'},inplace=True)

# %%
data_calo_hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            173 non-null    object
#  1   Domaine                 173 non-null    object
#  2   Code zone (FAO)         173 non-null    int64
#  3   Zone                    173 non-null    object
#  4   Code Élément            173 non-null    int64
#  5   Élément                 173 non-null    object
#  6   Code Produit            173 non-null    int64
#  7   Produit                 173 non-null    object
#  8   Code année              173 non-null    int64
#  9   Année                   173 non-null    int64
#  10  Unité                   173 non-null    object
#  11  Calo_hab                173 non-null    int64
#  12  Symbole                 173 non-null    object
#  13  Description du Symbole  173 non-null    object
# dtypes: int64(6), object(8)
# ...

# %%
data_calo_hab=data_calo_hab[-(data_calo_hab['Zone']=='Chine')]

# %%
data_calo_hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 172 entries, 0 to 172
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            172 non-null    object
#  1   Domaine                 172 non-null    object
#  2   Code zone (FAO)         172 non-null    int64
#  3   Zone                    172 non-null    object
#  4   Code Élément            172 non-null    int64
#  5   Élément                 172 non-null    object
#  6   Code Produit            172 non-null    int64
#  7   Produit                 172 non-null    object
#  8   Code année              172 non-null    int64
#  9   Année                   172 non-null    int64
#  10  Unité                   172 non-null    object
#  11  Calo_hab                172 non-null    int64
#  12  Symbole                 172 non-null    object
#  13  Description du Symbole  172 non-null    object
# dtypes: int64(6), object(8)
# ...

# %%
data_calo_hab
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           664
# 1                            Afrique du Sud           664
# ...

# %%
data_calo_hab[data_calo_hab['Zone']=='France']
# Out:
#    Code Domaine                      Domaine  Code zone (FAO)    Zone  \
# 58          FBS  Nouveaux Bilans Alimentaire               68  France
#
#     Code Élément                                         Élément  \
# 58           664  Disponibilité alimentaire (Kcal/personne/jour)
#
#     Code Produit        Produit  Code année  Année               Unité  \
# 58          2901  Total General        2018   2018  Kcal/personne/jour
#
#     Calo_hab Symbole Description du Symbole
# 58      3502      Fc        Donnée calculée

# %%
data_calo_hab
# Out:
#     Code Domaine                      Domaine  Code zone (FAO)  \
# 0            FBS  Nouveaux Bilans Alimentaire                2
# 1            FBS  Nouveaux Bilans Alimentaire              202
# 2            FBS  Nouveaux Bilans Alimentaire                3
# 3            FBS  Nouveaux Bilans Alimentaire                4
# 4            FBS  Nouveaux Bilans Alimentaire               79
# ..           ...                          ...              ...
# 168          FBS  Nouveaux Bilans Alimentaire              236
# 169          FBS  Nouveaux Bilans Alimentaire              237
# 170          FBS  Nouveaux Bilans Alimentaire              249
# 171          FBS  Nouveaux Bilans Alimentaire              251
# 172          FBS  Nouveaux Bilans Alimentaire              181
#
#                                        Zone  Code Élément  \
# 0                               Afghanistan           664
# 1                            Afrique du Sud           664
# ...

# %%
data_popul_prot_cal=data_proteines_popul.merge(data_calo_hab[['Zone','Calo_hab']], how='left',on=['Zone'])

# %%
data_popul_prot_cal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 0 to 170
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            171 non-null    object
#  1   Domaine                 171 non-null    object
#  2   Code zone (FAO)         171 non-null    int64
#  3   Zone                    171 non-null    object
#  4   Code Élément            171 non-null    int64
#  5   Élément                 171 non-null    object
#  6   Code Produit            171 non-null    int64
#  7   Produit                 171 non-null    object
#  8   Code année              171 non-null    int64
#  9   Année                   171 non-null    int64
#  10  Unité                   171 non-null    object
#  11  Valeur_x                171 non-null    float64
#  12  Symbole                 171 non-null    object
#  13  Description du Symbole  171 non-null    object
# ...

# %%
data=data_popul_prot_cal

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 0 to 170
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            171 non-null    object
#  1   Domaine                 171 non-null    object
#  2   Code zone (FAO)         171 non-null    int64
#  3   Zone                    171 non-null    object
#  4   Code Élément            171 non-null    int64
#  5   Élément                 171 non-null    object
#  6   Code Produit            171 non-null    int64
#  7   Produit                 171 non-null    object
#  8   Code année              171 non-null    int64
#  9   Année                   171 non-null    int64
#  10  Unité                   171 non-null    object
#  11  Valeur_x                171 non-null    float64
#  12  Symbole                 171 non-null    object
#  13  Description du Symbole  171 non-null    object
# ...

# %%
data6=data

# %%
data6
# Out:
#     Code Domaine                       Domaine  Code zone (FAO)  \
# 0             OA  Séries temporelles annuelles                2
# 1             OA  Séries temporelles annuelles              202
# 2             OA  Séries temporelles annuelles                3
# 3             OA  Séries temporelles annuelles                4
# 4             OA  Séries temporelles annuelles               79
# ..           ...                           ...              ...
# 166           OA  Séries temporelles annuelles              236
# 167           OA  Séries temporelles annuelles              237
# 168           OA  Séries temporelles annuelles              249
# 169           OA  Séries temporelles annuelles              251
# 170           OA  Séries temporelles annuelles              181
#
#                                        Zone  Code Élément            Élément  \
# 0                               Afghanistan           511  Population totale
# ...

# %%
data6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 0 to 170
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            171 non-null    object
#  1   Domaine                 171 non-null    object
#  2   Code zone (FAO)         171 non-null    int64
#  3   Zone                    171 non-null    object
#  4   Code Élément            171 non-null    int64
#  5   Élément                 171 non-null    object
#  6   Code Produit            171 non-null    int64
#  7   Produit                 171 non-null    object
#  8   Code année              171 non-null    int64
#  9   Année                   171 non-null    int64
#  10  Unité                   171 non-null    object
#  11  Valeur_x                171 non-null    float64
#  12  Symbole                 171 non-null    object
#  13  Description du Symbole  171 non-null    object
# ...

# %% [markdown]
# # Classification ascendante hiérarchique

# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
from sklearn import preprocessing 
# Data set
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
data7 = data6.set_index('Zone')
data7=data7[['diff_popu_pourc','Prop_prot','prot_hab','Calo_hab']]

# préparation des données pour le clustering
X = data7

#Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X) 
X_scaled = std_scale.transform(X)

#Clustering hiérarchique¶
Z = linkage(X_scaled, 'ward') 

 
# Plot with Custom leaves
dendrogram(Z, leaf_rotation=90, leaf_font_size=8,color_threshold=6)#, labels=data7.index)
plt.axhline(y = 6, linewidth = 1, color = "red", linestyle = "--")
plt.ylabel('distance entre clusters')
#plt.text(1, 6, "6") 
# Show the graph
plt.show()

# %%
data7
# Out:
#                                         diff_popu_pourc  Prop_prot  prot_hab  \
# Zone
# Afghanistan                                    8.015197   0.194344   0.05552
# Afrique du Sud                                 4.344302   0.427048   0.08437
# Albanie                                       -0.268914   0.533523   0.11574
# Algérie                                        6.293751   0.269302   0.09183
# Allemagne                                      1.634734   0.607495   0.10540
# ...                                                 ...        ...       ...
# Venezuela (République bolivarienne du)        -3.971537   0.453572   0.05417
# Viet Nam                                       3.095572   0.402313   0.09858
# Yémen                                          7.550768   0.190389   0.05452
# Zambie                                         9.272080   0.226334   0.06053
# Zimbabwe                                       4.518203   0.262514   0.04415
#
# ...

# %%
from scipy.cluster.hierarchy import linkage,fcluster
clusters = fcluster(Z, 5, criterion='maxclust')
print(clusters)
# Out:
# [2 1 3 4 3 2 5 4 3 5 3 3 4 5 1 3 3 3 1 2 1 5 1 3 5 2 1 1 2 3 3 3 3 4 5 3 5
#  1 5 2 3 5 3 1 5 4 5 4 1 3 3 1 3 2 3 5 3 1 2 5 2 3 5 1 2 2 5 2 1 3 2 1 1 4
#  2 3 3 3 3 5 5 1 3 2 1 5 3 1 3 1 2 3 3 5 2 5 2 1 1 3 4 5 1 3 5 3 2 5 1 1 1
#  2 2 3 5 3 1 2 4 1 5 1 3 1 1 3 3 3 2 3 5 1 5 2 2 3 3 2 5 5 3 3 2 2 5 2 5 3
#  1 1 3 3 1 2 2 3 5 2 2 5 4 1 4 5 3 1 5 4 2 2 2]

# %%
data7['Clusters']=clusters

# %%
data7
# Out:
#                                         diff_popu_pourc  Prop_prot  prot_hab  \
# Zone
# Afghanistan                                    8.015197   0.194344   0.05552
# Afrique du Sud                                 4.344302   0.427048   0.08437
# Albanie                                       -0.268914   0.533523   0.11574
# Algérie                                        6.293751   0.269302   0.09183
# Allemagne                                      1.634734   0.607495   0.10540
# ...                                                 ...        ...       ...
# Venezuela (République bolivarienne du)        -3.971537   0.453572   0.05417
# Viet Nam                                       3.095572   0.402313   0.09858
# Yémen                                          7.550768   0.190389   0.05452
# Zambie                                         9.272080   0.226334   0.06053
# Zimbabwe                                       4.518203   0.262514   0.04415
#
# ...

# %%
dataclus_1=data7[data7['Clusters']==1]

# %%
dataclus_1.describe()
# Out:
#        diff_popu_pourc  Prop_prot   prot_hab     Calo_hab  Clusters
# count        37.000000  37.000000  37.000000    37.000000      37.0
# mean          5.670522   0.359241   0.070740  2637.675676       1.0
# std           2.623257   0.092478   0.008186   184.367998       0.0
# min           1.534033   0.191014   0.058160  2235.000000       1.0
# 25%           3.996564   0.288400   0.065230  2533.000000       1.0
# 50%           5.001471   0.361179   0.068990  2662.000000       1.0
# 75%           6.419053   0.425254   0.076930  2769.000000       1.0
# max          13.360958   0.603887   0.088620  2940.000000       1.0

# %%
dataclus_1
# Out:
#                                        diff_popu_pourc  Prop_prot  prot_hab  \
# Zone
# Afrique du Sud                                4.344302   0.427048   0.08437
# Bangladesh                                    3.276945   0.206817   0.06073
# Belize                                        6.133548   0.428472   0.07193
# Bolivie (État plurinational de)               4.447323   0.484162   0.07324
# Botswana                                      6.288065   0.425254   0.06589
# Cabo Verde                                    3.625394   0.367203   0.07086
# Cambodge                                      4.692581   0.288400   0.06595
# Congo                                         7.995395   0.453748   0.05816
# Djibouti                                      4.915793   0.213232   0.06575
# Équateur                                      5.380810   0.465888   0.06596
# Eswatini                                      2.919902   0.281295   0.06207
# ...

# %%
dataclus_2=data7[data7['Clusters']==2]

# %%
dataclus_2
# Out:
#                                             diff_popu_pourc  Prop_prot  \
# Zone
# Afghanistan                                        8.015197   0.194344
# Angola                                            10.491199   0.307446
# Bénin                                              8.595841   0.194622
# Burkina Faso                                       9.060107   0.142340
# Cameroun                                           8.231903   0.156628
# Côte d'Ivoire                                      7.935398   0.247700
# Éthiopie                                           8.319450   0.098749
# Gambie                                             9.311938   0.254976
# Ghana                                              6.886721   0.249513
# Guinée                                             8.591650   0.197909
# Guinée-Bissau                                      7.892059   0.213312
# Haïti                                              3.998264   0.213422
# ...

# %%
dataclus_2.describe()
# Out:
#        diff_popu_pourc  Prop_prot   prot_hab     Calo_hab  Clusters
# count        36.000000  36.000000  36.000000    36.000000      36.0
# mean          7.865428   0.217161   0.057405  2337.472222       2.0
# std           2.074628   0.065349   0.009651   295.355620       0.0
# min           1.452404   0.098749   0.042410  1786.000000       2.0
# 25%           7.498054   0.184817   0.052543  2113.500000       2.0
# 50%           8.170764   0.213367   0.057815  2353.500000       2.0
# 75%           8.828807   0.250879   0.061902  2551.750000       2.0
# max          12.204780   0.443472   0.082600  3035.000000       2.0

# %%
dataclus_3=data7[data7['Clusters']==3]

# %%
dataclus_3
# Out:
#                                                     diff_popu_pourc  \
# Zone
# Albanie                                                   -0.268914
# Allemagne                                                  1.634734
# Argentine                                                  2.984844
# Australie                                                  4.034889
# Autriche                                                   2.451162
# Barbade                                                    0.461581
# Bélarus                                                    0.139775
# Belgique                                                   1.720757
# Brésil                                                     2.444129
# Canada                                                     2.908639
# Chili                                                      4.228349
# Chine - RAS de Hong-Kong                                   2.584666
# Chine - RAS de Macao                                       4.908111
# ...

# %%
dataclus_3.describe()
# Out:
#        diff_popu_pourc  Prop_prot   prot_hab     Calo_hab  Clusters
# count        51.000000  51.000000  51.000000    51.000000      51.0
# mean          1.499675   0.591904   0.104778  3346.078431       3.0
# std           2.279423   0.055827   0.012402   216.065531       0.0
# min          -4.455025   0.489399   0.086500  2910.000000       3.0
# 25%           0.230133   0.548595   0.094740  3215.500000       3.0
# 50%           1.351847   0.597880   0.105400  3344.000000       3.0
# 75%           2.707242   0.624793   0.111450  3475.500000       3.0
# max           7.866350   0.730880   0.146130  3885.000000       3.0

# %%
dataclus_4=data7[data7['Clusters']==4]

# %%
dataclus_4
# Out:
#                                 diff_popu_pourc  Prop_prot  prot_hab  \
# Zone
# Algérie                                6.293751   0.269302   0.09183
# Arabie saoudite                        6.258622   0.376582   0.08694
# Azerbaïdjan                            3.396037   0.344524   0.09442
# Chine, continentale                    1.478477   0.399272   0.10166
# Égypte                                 6.470020   0.270919   0.09752
# Émirats arabes unis                    3.973475   0.457646   0.11026
# Iran (République islamique d')         4.214396   0.288580   0.08573
# Maroc                                  3.939262   0.274931   0.10108
# Ouzbékistan                            5.000676   0.383081   0.09327
# Tunisie                                3.445919   0.286716   0.09982
# Turquie                                4.852550   0.356885   0.11068
# Viet Nam                               3.095572   0.402313   0.09858
#
#                                 Calo_hab  Clusters
# Zone
# ...

# %%
dataclus_4.describe()
# Out:
#        diff_popu_pourc  Prop_prot   prot_hab     Calo_hab  Clusters
# count        12.000000  12.000000  12.000000    12.000000      12.0
# mean          4.368230   0.342563   0.097649  3273.833333       4.0
# std           1.491276   0.063350   0.007877   198.332518       0.0
# min           1.478477   0.269302   0.085730  3011.000000       4.0
# 25%           3.433449   0.283770   0.092910  3133.500000       4.0
# 50%           4.093936   0.350705   0.098050  3299.500000       4.0
# 75%           5.315163   0.387129   0.101225  3344.500000       4.0
# max           6.470020   0.457646   0.110680  3711.000000       4.0

# %%
dataclus_5=data7[data7['Clusters']==5]

# %%
dataclus_5
# Out:
#                                         diff_popu_pourc  Prop_prot  prot_hab  \
# Zone
# Antigua-et-Barbuda                             2.907039   0.645218   0.08019
# Arménie                                        0.895284   0.480551   0.09435
# Bahamas                                        3.054735   0.649399   0.08069
# Bosnie-Herzégovine                            -3.074509   0.374216   0.09882
# Bulgarie                                      -2.057477   0.503963   0.08326
# Chine, Taiwan Province de                      0.717322   0.505568   0.08620
# Colombie                                       4.504106   0.511657   0.07292
# Costa Rica                                     3.127952   0.557753   0.08242
# Cuba                                           0.117910   0.405701   0.08489
# Dominique                                      0.620935   0.555387   0.07908
# El Salvador                                    1.511781   0.349344   0.07703
# ...

# %%
dataclus_5.describe()
# Out:
#        diff_popu_pourc  Prop_prot   prot_hab     Calo_hab  Clusters
# count        35.000000  35.000000  35.000000    35.000000      35.0
# mean          1.329818   0.504439   0.079761  2827.685714       5.0
# std           2.227318   0.080423   0.009397   257.741523       0.0
# min          -3.971537   0.349344   0.054170  2120.000000       5.0
# 25%           0.146219   0.448070   0.074760  2684.500000       5.0
# 50%           1.508147   0.503963   0.080690  2845.000000       5.0
# 75%           2.980887   0.556920   0.086010  2994.000000       5.0
# max           5.728881   0.651128   0.098820  3344.000000       5.0

# %%
data7[data7['Clusters']==1].describe()
# Out:
#        diff_popu_pourc  Prop_prot   prot_hab     Calo_hab  Clusters
# count        37.000000  37.000000  37.000000    37.000000      37.0
# mean          5.670522   0.359241   0.070740  2637.675676       1.0
# std           2.623257   0.092478   0.008186   184.367998       0.0
# min           1.534033   0.191014   0.058160  2235.000000       1.0
# 25%           3.996564   0.288400   0.065230  2533.000000       1.0
# 50%           5.001471   0.361179   0.068990  2662.000000       1.0
# 75%           6.419053   0.425254   0.076930  2769.000000       1.0
# max          13.360958   0.603887   0.088620  2940.000000       1.0

# %%
sns.boxplot(x=data7['Clusters'],y=data7['diff_popu_pourc'])

# %%
sns.boxplot(x=data7['Clusters'],y=data7['Prop_prot']) #ajouter la moyenne

# %%
sns.boxplot(x=data7['Clusters'],y=data7['prot_hab'])

# %%
sns.boxplot(x=data7['Clusters'],y=data7['Calo_hab'])

# %% [markdown]
#  # Choix du cluster : cluster 3¶

# %%
dataclus_3
# Out:
#                                                     diff_popu_pourc  \
# Zone
# Albanie                                                   -0.268914
# Allemagne                                                  1.634734
# Argentine                                                  2.984844
# Australie                                                  4.034889
# Autriche                                                   2.451162
# Barbade                                                    0.461581
# Bélarus                                                    0.139775
# Belgique                                                   1.720757
# Brésil                                                     2.444129
# Canada                                                     2.908639
# Chili                                                      4.228349
# Chine - RAS de Hong-Kong                                   2.584666
# Chine - RAS de Macao                                       4.908111
# ...

# %% [markdown]
# #  Analyse en composante principale :ACP

# %%
data8=data6[['Zone','diff_popu_pourc','Prop_prot','prot_hab','Calo_hab']]

# %%
data8
# Out:
#                                        Zone  diff_popu_pourc  Prop_prot  \
# 0                               Afghanistan         8.015197   0.194344
# 1                            Afrique du Sud         4.344302   0.427048
# 2                                   Albanie        -0.268914   0.533523
# 3                                   Algérie         6.293751   0.269302
# 4                                 Allemagne         1.634734   0.607495
# ..                                      ...              ...        ...
# 166  Venezuela (République bolivarienne du)        -3.971537   0.453572
# 167                                Viet Nam         3.095572   0.402313
# 168                                   Yémen         7.550768   0.190389
# 169                                  Zambie         9.272080   0.226334
# 170                                Zimbabwe         4.518203   0.262514
#
#      prot_hab  Calo_hab
# 0     0.05552      2040
# 1     0.08437      2899
# 2     0.11574      3360
# ...

# %%
data8['Clusters']=clusters
# Out:
# <ipython-input-90-a93cc9bc6a1b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data8['Clusters']=clusters

# %%
data8
# Out:
#                                        Zone  diff_popu_pourc  Prop_prot  \
# 0                               Afghanistan         8.015197   0.194344
# 1                            Afrique du Sud         4.344302   0.427048
# 2                                   Albanie        -0.268914   0.533523
# 3                                   Algérie         6.293751   0.269302
# 4                                 Allemagne         1.634734   0.607495
# ..                                      ...              ...        ...
# 166  Venezuela (République bolivarienne du)        -3.971537   0.453572
# 167                                Viet Nam         3.095572   0.402313
# 168                                   Yémen         7.550768   0.190389
# 169                                  Zambie         9.272080   0.226334
# 170                                Zimbabwe         4.518203   0.262514
#
#      prot_hab  Calo_hab  Clusters
# 0     0.05552      2040         2
# ...

# %%
data_pays=data8[['Zone','Clusters']]

# %%
data_pays
# Out:
#                                        Zone  Clusters
# 0                               Afghanistan         2
# 1                            Afrique du Sud         1
# 2                                   Albanie         3
# 3                                   Algérie         4
# 4                                 Allemagne         3
# ..                                      ...       ...
# 166  Venezuela (République bolivarienne du)         5
# 167                                Viet Nam         4
# 168                                   Yémen         2
# 169                                  Zambie         2
# 170                                Zimbabwe         2
#
# [171 rows x 2 columns]

# %%
data_pays.to_csv('C:\\Users\\nassc\Desktop\\data_pays.csv', index = False)

# %%
from sklearn import preprocessing
from sklearn import decomposition
# choix du nombre de composantes à calculer
n_comp = 4
# suppression des colonnes non numériques
data8_num = data8.drop(columns =["Zone",'Clusters'])
X = data8_num
# Centrage et Réduction

std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)
# Calcul des composantes principales
pca = decomposition.PCA()

#pca = PCA()
pca.fit(X_scaled)
# Out:
# PCA()

# %%
print(pca.explained_variance_)
print(pca.explained_variance_ratio_)
# Out:
# [2.93902991 0.62323952 0.3641983  0.09706168]
# [0.73046065 0.15489871 0.09051712 0.02412352]

# %%
eig = pd.DataFrame(
    {
        "Dimension" : ["Dim" + str(x + 1) for x in range(4)], 
        "Variance expliquée" : pca.explained_variance_,
        "% variance expliquée" : np.round(pca.explained_variance_ratio_ * 100),
        "% cum. var. expliquée" : np.round(np.cumsum(pca.explained_variance_ratio_) * 100)
    }
)
eig
# Out:
#   Dimension  Variance expliquée  % variance expliquée  % cum. var. expliquée
# 0      Dim1            2.939030                  73.0                   73.0
# 1      Dim2            0.623240                  15.0                   89.0
# 2      Dim3            0.364198                   9.0                   98.0
# 3      Dim4            0.097062                   2.0                  100.0

# %%
eig.plot.bar(x = "Dimension", y = "% variance expliquée") # permet un diagramme en barres
#plt.text(5, 18, "15%") # ajout de texte
plt.axhline(y = 17, linewidth = .5, color = "dimgray", linestyle = "--") # ligne 17 = 100 / 6 (nb dimensions)
plt.show()

# %%
data8_pca = pca.transform(X_scaled)

# %%
data8_pca_df = pd.DataFrame({
    "Dim1" : data8_pca[:,0], 
    "Dim2" : data8_pca[:,1],
    "Zone" : data8["Zone"],
    "Clusters" : data8['Clusters']})

# Résultat (premières lignes)
data8_pca_df
# Out:
#          Dim1      Dim2                                    Zone  Clusters
# 0   -2.885761  0.073537                             Afghanistan         2
# 1    0.045980 -0.176126                          Afrique du Sud         1
# 2    2.304741 -0.026539                                 Albanie         3
# 3   -0.011131 -1.344474                                 Algérie         4
# 4    2.254530 -0.365238                               Allemagne         3
# ..        ...       ...                                     ...       ...
# 166 -0.522348  3.063630  Venezuela (République bolivarienne du)         5
# 167  0.639436 -0.306341                                Viet Nam         4
# 168 -2.735274  0.086275                                   Yémen         2
# 169 -2.854263 -0.235815                                  Zambie         2
# 170 -2.685215  1.291411                                Zimbabwe         2
#
# [171 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
def display_circles(pcs, n_comp, pca, axis_ranks, labels=None, label_rotation=0, lims=None):
    for d1, d2 in axis_ranks: # On affiche les 3 premiers plans factoriels, donc les 6 premières composantes
        if d2 < n_comp:

            # initialisation de la figure
            fig, ax = plt.subplots(figsize=(7,6))

            # détermination des limites du graphique
            if lims is not None :
                xmin, xmax, ymin, ymax = lims
            elif pcs.shape[1] < 30 :
                xmin, xmax, ymin, ymax = -1, 1, -1, 1
            else :
                xmin, xmax, ymin, ymax = min(pcs[d1,:]), max(pcs[d1,:]), min(pcs[d2,:]), max(pcs[d2,:])

            # affichage des flèches
            # s'il y a plus de 30 flèches, on n'affiche pas le triangle à leur extrémité
            if pcs.shape[1] < 30 :
                plt.quiver(np.zeros(pcs.shape[1]), np.zeros(pcs.shape[1]),
                   pcs[d1,:], pcs[d2,:], 
                   angles='xy', scale_units='xy', scale=1, color="grey")
                # (voir la doc : https://matplotlib.org/api/_as_gen/matplotlib.pyplot.quiver.html)
            else:
                lines = [[[0,0],[x,y]] for x,y in pcs[[d1,d2]].T]
                ax.add_collection(LineCollection(lines, axes=ax, alpha=.1, color='black'))
            
            # affichage des noms des variables  
            if labels is not None:  
                for i,(x, y) in enumerate(pcs[[d1,d2]].T):
                    if x >= xmin and x <= xmax and y >= ymin and y <= ymax :
                        plt.text(x, y, labels[i], fontsize='14', ha='center', va='center', rotation=label_rotation, color="blue", alpha=0.5)
            
            # affichage du cercle
            circle = plt.Circle((0,0), 1, facecolor='none', edgecolor='b')
            plt.gca().add_artist(circle)

            # définition des limites du graphique
            plt.xlim(xmin, xmax)
            plt.ylim(ymin, ymax)
        
            # affichage des lignes horizontales et verticales
            plt.plot([-1, 1], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-1, 1], color='grey', ls='--')

            # nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Cercle des corrélations (F{} et F{})".format(d1+1, d2+1))
            plt.show(block=False)
def display_factorial_planes(X_projected, n_comp, pca, axis_ranks, labels=None, alpha=1, illustrative_var=None):
    for d1,d2 in axis_ranks:
        if d2 < n_comp:
 
            # initialisation de la figure       
            fig = plt.figure(figsize=(7,6))
        
            # affichage des points
            if illustrative_var is None:
                plt.scatter(X_projected[:, d1], X_projected[:, d2], c=clusters.astype(np.float),cmap = 'jet', alpha=.7)
            else:
                illustrative_var = np.array(illustrative_var)
                for value in np.unique(illustrative_var):
                    selected = np.where(illustrative_var == value)
                    plt.scatter(X_projected[selected, d1], X_projected[selected, d2], cmap = 'jet', alpha=.7)
                    
            centroides1=data8_pca_df[['Dim1','Dim2','Clusters']].groupby('Clusters').mean()
            plt.scatter(centroides1['Dim1'],centroides1['Dim2'],marker='x',color='red')    

            # affichage des labels des points
            if labels is not None:
                for i,(x,y) in enumerate(X_projected[:,[d1,d2]]):
                    plt.text(x, y, labels[i],
                              fontsize='14', ha='center',va='center') 
               
            # détermination des limites du graphique
            boundary = np.max(np.abs(X_projected[:, [d1,d2]])) * 1.1
            plt.xlim([-boundary,boundary])
            plt.ylim([-boundary,boundary])
        
            # affichage des lignes horizontales et verticales
            plt.plot([-100, 100], [0, 0], color='grey', ls='--')
            plt.plot([0, 0], [-100, 100], color='grey', ls='--')

            
#plt.title("Projection des {} centres sur le 1e plan factoriel".format(len(centroids)))

            #nom des axes, avec le pourcentage d'inertie expliqué
            plt.xlabel('F{} ({}%)'.format(d1+1, round(100*pca.explained_variance_ratio_[d1],1)))
            plt.ylabel('F{} ({}%)'.format(d2+1, round(100*pca.explained_variance_ratio_[d2],1)))

            plt.title("Projection des individus (sur F{} et F{})".format(d1+1, d2+1))
            
            plt.show(block=False)

# %%
import pandas as pd
import numpy as np
from sklearn import decomposition
from sklearn import preprocessing
import matplotlib.patches as mpatches

# choix du nombre de composantes à calculer
n_comp = 4

# import de l'échantillon
#data = pd.read_csv("my_courses.csv",decimal=".",index_col=0)

# selection des colonnes à prendre en compte dans l'ACP
data_pca = data8[['diff_popu_pourc','Prop_prot','prot_hab','Calo_hab']]

# préparation des données pour l'ACP
#data_pca = data_pca.fillna(data_pca.mean()) # Il est fréquent de remplacer les valeurs inconnues par la moyenne de la variable
X = data_pca.values
names = data8['Clusters'] # ou data.index pour avoir les intitulés
features = data_pca.columns

# Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X)
X_scaled = std_scale.transform(X)

# Calcul des composantes principales
pca = decomposition.PCA(n_components=n_comp)
pca.fit(X_scaled)

# Eboulis des valeurs propres
#display_scree_plot(pca)

# Cercle des corrélations
pcs = pca.components_
display_circles(pcs, n_comp, pca, [(0,1),(2,3),(4,5)], labels = np.array(features))

# Projection des individus
X_projected = pca.transform(X_scaled)
display_factorial_planes(X_projected, n_comp, pca, [(0,1),(2,3),(4,5)], labels = np.array(names))


#centroides1=data8_pca_df[['Dim1','Dim2','Clusters']].groupby('Clusters').mean()
#plt.scatter(centroides1['Dim1'],centroides1['Dim2'],marker='x')
#plt.title("Projection des {} centres sur le 1e plan factoriel".format(len(centroids)))
plt.show()

# %% [markdown]
# # les 3 variables :prot_hab,Prop_prot et Calo_hab sont bien corrélées à l'axe 1(DIM1)
# # et la variables diff_popu_pourc est négativement corrélée à dim1 et dim2

# %%
data8_pca_df
# Out:
#          Dim1      Dim2                                    Zone  Clusters
# 0   -2.885761  0.073537                             Afghanistan         2
# 1    0.045980 -0.176126                          Afrique du Sud         1
# 2    2.304741 -0.026539                                 Albanie         3
# 3   -0.011131 -1.344474                                 Algérie         4
# 4    2.254530 -0.365238                               Allemagne         3
# ..        ...       ...                                     ...       ...
# 166 -0.522348  3.063630  Venezuela (République bolivarienne du)         5
# 167  0.639436 -0.306341                                Viet Nam         4
# 168 -2.735274  0.086275                                   Yémen         2
# 169 -2.854263 -0.235815                                  Zambie         2
# 170 -2.685215  1.291411                                Zimbabwe         2
#
# [171 rows x 4 columns]

# %% [markdown]
# # Les centroides des clusters

# %%
centroides1=data8_pca_df[['Dim1','Dim2','Clusters']].groupby('Clusters').mean()

# %%
centroides1
# Out:
#               Dim1      Dim2
# Clusters
# 1        -0.989244 -0.053047
# 2        -2.403439 -0.182911
# 3         1.966504 -0.143875
# 4         0.555383 -0.884004
# 5         0.461987  0.756948

# %%
centroides1.to_csv('C:\\Users\\nassc\Desktop\\centroides1.csv', index = False)

# %% [markdown]
# # Tests statistiques

# %% [markdown]
# # Test d'adéquation à la variable gaussienne

# %%
from scipy import stats
shapiro_test = stats.shapiro(data8['diff_popu_pourc'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.98711758852005, pvalue=0.11877255141735077)

# %% [markdown]
# # pvalue > 0,05. La variable diff_popu_pourc est gaussienne

# %%
from scipy import stats
shapiro_test = stats.shapiro(data8['Prop_prot'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.9555407166481018, pvalue=3.0547380447387695e-05)

# %% [markdown]
# # pvalue < 0,05. Pro_prot est non gaussienne¶

# %%
from scipy import stats
shapiro_test = stats.shapiro(data8['prot_hab'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.9824925661087036, pvalue=0.029962871223688126)

# %% [markdown]
# # pvalue < 0,05 . prot_hab est non gaussienne¶

# %%
from scipy import stats
shapiro_test = stats.shapiro(data8['Calo_hab'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.9865924119949341, pvalue=0.10162433981895447)

# %% [markdown]
# # pvalue > 0,05. Calo_hab est gaussienne¶

# %% [markdown]
# # Comparer deux clusteurs :  Cluster3,cluster4

# %% [markdown]
# # Comparaison des variances

# %%
from scipy.stats import levene
stat, p = levene(dataclus_3['diff_popu_pourc'],dataclus_4['diff_popu_pourc'])
print(p)
# Out:
# 0.22194586514791964

# %% [markdown]
# # pvalue > 0,05, H0 n'est pas rejetée : les deux variances sont égales

# %% [markdown]
# # Comparaison des moyennes

# %%
from scipy import stats
stats.ttest_ind(dataclus_3['diff_popu_pourc'],dataclus_4['diff_popu_pourc'],equal_var=True)
# Out:
# Ttest_indResult(statistic=-4.141734341312339, pvalue=0.00010777435476469085)

# %% [markdown]
# # P_value <0,05 H0 est rejetée , les deux moyennes sont différentes
#  # les deux clusters 3 et 4 sont différents¶¶

# %% [markdown]
# # Réduire la liste des pays à cibler : 2ème CAH

# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
 
# Data set
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
#dataclus_finalc = dataclus_3.set_index('Zone')
dataclus_finalc=dataclus_3[['diff_popu_pourc','Prop_prot','prot_hab','Calo_hab']]
# préparation des données pour le clustering
X = dataclus_finalc

#Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X) 
X_scaled = std_scale.transform(X)

#Clustering hiérarchique¶
Z = linkage(X_scaled, 'ward') 

 
# Plot with Custom leaves
dendrogram(Z, leaf_rotation=90, leaf_font_size=8,color_threshold=5)#, labels=data7.index)
plt.axhline(y = 5, linewidth = 1, color = "red", linestyle = "--")
plt.ylabel('distance entre clusters')
# Show the graph
plt.show()

# %%
from scipy.cluster.hierarchy import linkage,fcluster
clusters = fcluster(Z, 5, criterion='maxclust')
print(clusters)
# Out:
# [3 2 2 2 2 5 5 2 5 2 4 1 2 4 5 1 2 2 2 5 1 3 5 2 1 2 3 4 4 5 1 2 2 4 1 2 5
#  2 3 5 1 5 3 5 5 5 5 2 2 5 5]

# %%
dataclus_finalc['Clusters']=clusters

# %%
dataclus_finalc
# Out:
#                                                     diff_popu_pourc  \
# Zone
# Albanie                                                   -0.268914
# Allemagne                                                  1.634734
# Argentine                                                  2.984844
# Australie                                                  4.034889
# Autriche                                                   2.451162
# Barbade                                                    0.461581
# Bélarus                                                    0.139775
# Belgique                                                   1.720757
# Brésil                                                     2.444129
# Canada                                                     2.908639
# Chili                                                      4.228349
# Chine - RAS de Hong-Kong                                   2.584666
# Chine - RAS de Macao                                       4.908111
# ...

# %%
sns.boxplot(x=dataclus_finalc['Clusters'],y=dataclus_finalc['diff_popu_pourc'])

# %%
sns.boxplot(x=dataclus_finalc['Clusters'],y=dataclus_finalc['Prop_prot'])

# %%
sns.boxplot(x=dataclus_finalc['Clusters'],y=dataclus_finalc['prot_hab'])

# %%
sns.boxplot(x=dataclus_finalc['Clusters'],y=dataclus_finalc['Calo_hab'])

# %% [markdown]
# # Choix de la liste des pays à cibler

# %%
dataclus_finalc[dataclus_finalc['Clusters']==1]
# Out:
#                           diff_popu_pourc  Prop_prot  prot_hab  Calo_hab  \
# Zone
# Chine - RAS de Hong-Kong         2.584666   0.730880   0.12853      3267
# Danemark                         1.115036   0.680987   0.11708      3401
# Finlande                         0.756305   0.639291   0.11799      3343
# Islande                          1.959163   0.718401   0.14613      3654
# Lituanie                        -4.455025   0.622582   0.12665      3411
# Monténégro                       0.136054   0.613551   0.11453      3500
# Portugal                        -1.081734   0.635913   0.11695      3480
#
#                           Clusters
# Zone
# Chine - RAS de Hong-Kong         1
# Danemark                         1
# Finlande                         1
# Islande                          1
# Lituanie                         1
# Monténégro                       1
# Portugal                         1

# %% [markdown]
# # Réaliser une étude avecla variable PIB

# %%
data8_pca_df1=data8_pca_df[['Zone','Dim1']]

# %%
data8_pca_df1
# Out:
#                                        Zone      Dim1
# 0                               Afghanistan -2.885761
# 1                            Afrique du Sud  0.045980
# 2                                   Albanie  2.304741
# 3                                   Algérie -0.011131
# 4                                 Allemagne  2.254530
# ..                                      ...       ...
# 166  Venezuela (République bolivarienne du) -0.522348
# 167                                Viet Nam  0.639436
# 168                                   Yémen -2.735274
# 169                                  Zambie -2.854263
# 170                                Zimbabwe -2.685215
#
# [171 rows x 2 columns]

# %% [markdown]
# # IMPORTER la table PIB

# %%
data_PIB_hab=pd.read_csv('C:\\Users\\nassc\Desktop\\PIB_hab.csv')

# %%
data_PIB_hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            185 non-null    object
#  1   Domaine                 185 non-null    object
#  2   Code zone (FAO)         185 non-null    int64
#  3   Zone                    185 non-null    object
#  4   Code Élément            185 non-null    int64
#  5   Élément                 185 non-null    object
#  6   Code Produit            185 non-null    int64
#  7   Produit                 185 non-null    object
#  8   Code année              185 non-null    int64
#  9   Année                   185 non-null    int64
#  10  Unité                   185 non-null    object
#  11  Valeur                  185 non-null    float64
#  12  Symbole                 185 non-null    object
#  13  Description du Symbole  185 non-null    object
# ...

# %%
data_PIB_hab
# Out:
#     Code Domaine                             Domaine  Code zone (FAO)  \
# 0             FS  Données de la sécurité alimentaire                2
# 1             FS  Données de la sécurité alimentaire              202
# 2             FS  Données de la sécurité alimentaire                3
# 3             FS  Données de la sécurité alimentaire                4
# 4             FS  Données de la sécurité alimentaire               79
# ..           ...                                 ...              ...
# 180           FS  Données de la sécurité alimentaire              234
# 181           FS  Données de la sécurité alimentaire              155
# 182           FS  Données de la sécurité alimentaire              237
# 183           FS  Données de la sécurité alimentaire              251
# 184           FS  Données de la sécurité alimentaire              181
#
#                Zone  Code Élément Élément  Code Produit  \
# 0       Afghanistan          6126  Valeur         22013
# ...

# %%
data_PIB_hab3=data_PIB_hab[(data_PIB_hab['Zone'].isin(data8_pca_df1['Zone']))]

# %%
data_PIB_hab3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 184
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            163 non-null    object
#  1   Domaine                 163 non-null    object
#  2   Code zone (FAO)         163 non-null    int64
#  3   Zone                    163 non-null    object
#  4   Code Élément            163 non-null    int64
#  5   Élément                 163 non-null    object
#  6   Code Produit            163 non-null    int64
#  7   Produit                 163 non-null    object
#  8   Code année              163 non-null    int64
#  9   Année                   163 non-null    int64
#  10  Unité                   163 non-null    object
#  11  Valeur                  163 non-null    float64
#  12  Symbole                 163 non-null    object
#  13  Description du Symbole  163 non-null    object
# ...

# %%
data_PIB_hab3.rename(columns={'Valeur':'PIB_hab'},inplace=True)
# Out:
# C:\Users\nassc\anaconda3\lib\site-packages\pandas\core\frame.py:4125: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
data_PIB_hab3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 184
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Code Domaine            163 non-null    object
#  1   Domaine                 163 non-null    object
#  2   Code zone (FAO)         163 non-null    int64
#  3   Zone                    163 non-null    object
#  4   Code Élément            163 non-null    int64
#  5   Élément                 163 non-null    object
#  6   Code Produit            163 non-null    int64
#  7   Produit                 163 non-null    object
#  8   Code année              163 non-null    int64
#  9   Année                   163 non-null    int64
#  10  Unité                   163 non-null    object
#  11  PIB_hab                 163 non-null    float64
#  12  Symbole                 163 non-null    object
#  13  Description du Symbole  163 non-null    object
# ...

# %%
data_PIB_hab4=data_PIB_hab3[['Zone','PIB_hab']]

# %%
data_PIB_hab4.describe()
# Out:
#              PIB_hab
# count     163.000000
# mean    20431.583436
# std     21206.321132
# min       933.100000
# 25%      5035.800000
# 50%     12864.600000
# 75%     29152.850000
# max    131908.000000

# %%
data8_pca_PIB=data_PIB_hab4.merge(data8_pca_df1[['Zone','Dim1']], how='left',on=['Zone'])

# %%
data8_pca_PIB
# Out:
#                Zone  PIB_hab      Dim1
# 0       Afghanistan   2190.2 -2.885761
# 1    Afrique du Sud  12630.8  0.045980
# 2           Albanie  13601.3  2.304741
# 3           Algérie  11479.5 -0.011131
# 4         Allemagne  53660.0  2.254530
# ..              ...      ...       ...
# 158         Uruguay  21590.8  1.192710
# 159         Vanuatu   3129.9 -1.271476
# 160        Viet Nam   7586.4  0.639436
# 161          Zambie   3521.5 -2.854263
# 162        Zimbabwe   3130.0 -2.685215
#
# [163 rows x 3 columns]

# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn import preprocessing
import numpy as np
 
# Data set
#url = 'https://python-graph-gallery.com/wp-content/uploads/mtcars.csv'
#df = pd.read_csv(url)
#data8_pca_PIB = data8_pca_PIB.set_index('Zone')
data8_pca_PIB1=data8_pca_PIB[['Dim1','PIB_hab']]
# préparation des données pour le clustering
X = data8_pca_PIB1

#Centrage et Réduction
std_scale = preprocessing.StandardScaler().fit(X) 
X_scaled = std_scale.transform(X)

#Clustering hiérarchique¶
Z = linkage(X_scaled, 'ward') 

 
# Plot with Custom leaves
dendrogram(Z, leaf_rotation=90, leaf_font_size=8,color_threshold=3)#, labels=data7.index)
plt.axhline(y = 3, linewidth = 1, color = "red", linestyle = "--")
plt.ylabel('distance entre clusters')
# Show the graph
plt.show()

# %%
from scipy.cluster.hierarchy import linkage,fcluster
clusters = fcluster(Z, 7, criterion='maxclust')
print(clusters)
# Out:
# [4 7 3 7 2 4 6 3 3 6 2 2 7 6 5 6 6 2 7 5 7 6 7 6 6 5 7 5 5 2 6 2 1 6 3 7 5
#  6 5 3 2 5 7 7 7 2 7 3 3 5 2 4 3 7 2 7 5 7 5 3 7 5 5 4 7 4 5 3 5 5 7 5 2 2
#  3 3 7 3 5 6 4 7 7 3 5 3 7 4 3 1 6 4 6 4 7 5 3 7 6 7 6 7 3 4 7 5 5 5 5 4 2
#  3 7 4 7 5 6 7 2 7 7 3 3 5 3 7 7 7 4 3 2 4 6 6 6 7 5 5 6 4 6 3 5 7 2 2 7 4
#  4 3 7 5 4 6 7 7 3 6 6 5 7 4 4]

# %%
data8_pca_PIB['Clusters']=clusters

# %%
data8_pca_PIB
# Out:
#                Zone  PIB_hab      Dim1  Clusters
# 0       Afghanistan   2190.2 -2.885761         4
# 1    Afrique du Sud  12630.8  0.045980         7
# 2           Albanie  13601.3  2.304741         3
# 3           Algérie  11479.5 -0.011131         7
# 4         Allemagne  53660.0  2.254530         2
# ..              ...      ...       ...       ...
# 158         Uruguay  21590.8  1.192710         6
# 159         Vanuatu   3129.9 -1.271476         5
# 160        Viet Nam   7586.4  0.639436         7
# 161          Zambie   3521.5 -2.854263         4
# 162        Zimbabwe   3130.0 -2.685215         4
#
# [163 rows x 4 columns]

# %%
sns.boxplot(x=data8_pca_PIB['Clusters'],y=data8_pca_PIB['Dim1'])

# %%
sns.boxplot(x=data8_pca_PIB['Clusters'],y=data8_pca_PIB['PIB_hab'])

# %% [markdown]
# # Test d'déquation à la loi normale

# %%
from scipy import stats
shapiro_test = stats.shapiro(data8_pca_PIB['PIB_hab'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.7976395487785339, pvalue=9.537191864158676e-14)

# %% [markdown]
# # La variable 'PIB'n'est pas gaussienne

# %%
from scipy import stats
shapiro_test = stats.shapiro(data8_pca_PIB['Dim1'])
shapiro_test
# Out:
# ShapiroResult(statistic=0.9713907837867737, pvalue=0.0018609946127980947)

# %% [markdown]
# # La variable DIM1 n'est pas gaussienne

# %%
sns.distplot(data8_pca_PIB["Dim1"])

# %%
sns.distplot(data8_pca_PIB["PIB_hab"])
